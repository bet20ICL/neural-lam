# %%
import sys
import os

sys.path.append(os.path.dirname(os.getcwd()))

os.chdir("../")

# %% [markdown]
# # Border Mask

# %%
import os
import glob
import datetime as dt
import numpy as np
import torch

import neural_lam.constants as constants

# %%
full_grid = np.load("./data/era5_uk_big/static/nwp_xy.npy")
local_grid = np.load("./data/era5_uk_small/static/nwp_xy.npy")
print(full_grid.shape)
print(local_grid.shape)
# Out:
# (2, 81, 81)
# (2, 46, 40)

# %%
full_grid_2d = full_grid.reshape(2, -1).T
print(full_grid_2d.shape)
local_grid_2d = local_grid.reshape(2, -1).T
print(local_grid_2d.shape)
# Out:
# (6561, 2)
# (1840, 2)

# %%
mask = np.isin(full_grid_2d, local_grid_2d).all(axis=1)
print(mask.shape)
mask = 1.0 - mask.reshape(full_grid.shape[1:]).astype(int)
print(mask.shape)
np.save("test.npy", mask)
# Out:
# (6561,)
# (81, 81)

# %%
test_mask = np.load("data/meps_example/static/border_mask.npy")

# %%
test_mask
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
mask = np.load("./data/era5_uk_big/static/nwp_xy.npy")

# %%
for i in range(mask.shape[0]):
    for j in range(mask.shape[1]):
        print(mask[i, j], end="")
    print()
# Out:
# 111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 111111111111111111111111111111111111111111111111111111111111111111111111111111111
# ...
